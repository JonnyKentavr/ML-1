# 4    0.001404  0.013119  0.11607  ...  1.508468  1.334511  1.610694  1.685021
#
#      Delta7    Delta8    Delta9   Delta10   Delta11   Delta12
# 0  1.451240  1.440295  1.403678  1.405495  1.416705  1.354610
# 1  1.354242  1.365692  1.322870  1.314549  1.318999  1.323508
# 2  1.455996  1.368882  1.438053  1.388910  1.305469  1.305402
# 3  1.472926  1.643177  1.551286  1.638346  1.604008  1.621456
# 4  1.417614  1.574895  1.640088  1.533666  1.297536  1.382023
#
# [5 rows x 48 columns]

# %%
data.tail()
# Out:
#           ID  Recording  Status  Gender  Jitter_rel  Jitter_abs  Jitter_RAP  \
# 235  PARK-39          2       1       0     0.57585    0.000037    0.003701
# 236  PARK-39          3       1       0     0.23322    0.000015    0.001270
# 237  PARK-40          1       1       0     0.26862    0.000022    0.001354
# 238  PARK-40          2       1       0     0.45376    0.000037    0.002724
# 239  PARK-40          3       1       0     0.34706    0.000028    0.001746
#
#      Jitter_PPQ  Shim_loc  Shim_dB  ...    Delta3    Delta4    Delta5  \
# 235    0.005149  0.016868  0.14928  ...  1.116409  1.104511  1.099866
# 236    0.001497  0.017923  0.16720  ...  1.107477  1.083859  1.101819
# 237    0.001615  0.028040  0.24182  ...  1.335189  1.385580  1.281551
# 238    0.002258  0.064605  0.58002  ...  1.327629  1.349928  1.461323
# 239    0.002060  0.019914  0.17087  ...  1.440003  1.327946  1.531764
#
#        Delta6    Delta7    Delta8    Delta9   Delta10   Delta11   Delta12
# 235  1.080320  1.154057  1.117423  1.167076  1.132436  1.107824  1.109144
# 236  1.114161  1.090095  1.140705  1.126667  1.158444  1.096073  1.141835
# 237  1.367171  1.319055  1.367095  1.343193  1.374330  1.383364  1.456409
# 238  1.350599  1.346363  1.415338  1.361937  1.331923  1.423062  1.307353
# 239  1.471198  1.445675  1.415942  1.304214  1.395653  1.315691  1.422534
#
# [5 rows x 48 columns]

# %%
data.shape
# Out:
# (240, 48)

# %%
data.columns
# Out:
# Index(['ID', 'Recording', 'Status', 'Gender', 'Jitter_rel', 'Jitter_abs',
#        'Jitter_RAP', 'Jitter_PPQ', 'Shim_loc', 'Shim_dB', 'Shim_APQ3',
#        'Shim_APQ5', 'Shi_APQ11', 'HNR05', 'HNR15', 'HNR25', 'HNR35', 'HNR38',
#        'RPDE', 'DFA', 'PPE', 'GNE', 'MFCC0', 'MFCC1', 'MFCC2', 'MFCC3',
#        'MFCC4', 'MFCC5', 'MFCC6', 'MFCC7', 'MFCC8', 'MFCC9', 'MFCC10',
#        'MFCC11', 'MFCC12', 'Delta0', 'Delta1', 'Delta2', 'Delta3', 'Delta4',
#        'Delta5', 'Delta6', 'Delta7', 'Delta8', 'Delta9', 'Delta10', 'Delta11',
#        'Delta12'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=240, step=1)

# %%
data.at[2, 'Recording']
# Out:
# 3

# %%
data['ID']
# Out:
# 0      CONT-01
# 1      CONT-01
# 2      CONT-01
# 3      CONT-02
# 4      CONT-02
#         ...
# 235    PARK-39
# 236    PARK-39
# 237    PARK-40
# 238    PARK-40
# 239    PARK-40
# Name: ID, Length: 240, dtype: object

# %%
data[['ID', 'Status', 'Gender']].head()
# Out:
#         ID  Status  Gender
# 0  CONT-01       0       1
# 1  CONT-01       0       1
# 2  CONT-01       0       1
# 3  CONT-02       0       0
# 4  CONT-02       0       0

# %%
data.describe()
# Out:
#         Recording      Status      Gender  Jitter_rel  Jitter_abs  Jitter_RAP  \
# count  240.000000  240.000000  240.000000  240.000000  240.000000  240.000000
# mean     2.000000    0.500000    0.400000    0.583987    0.000044    0.003172
# std      0.818203    0.501045    0.490922    0.535769    0.000045    0.003373
# min      1.000000    0.000000    0.000000    0.148010    0.000007    0.000678
# 25%      1.000000    0.000000    0.000000    0.298260    0.000019    0.001551
# 50%      2.000000    0.500000    0.000000    0.481455    0.000035    0.002337
# 75%      3.000000    1.000000    1.000000    0.681685    0.000056    0.003678
# max      3.000000    1.000000    1.000000    6.838200    0.000550    0.043843
#
#        Jitter_PPQ    Shim_loc     Shim_dB   Shim_APQ3  ...      Delta3  \
# count  240.000000  240.000000  240.000000  240.000000  ...  240.000000
# mean     0.003532    0.038428    0.336832    0.021499  ...    1.343238
# std      0.004449    0.023213    0.205905    0.013787  ...    0.198174
# min      0.001036    0.007444    0.064989    0.003344  ...    0.766458
# 25%      0.001867    0.024336    0.211785    0.012909  ...    1.208624
# 50%      0.002870    0.032960    0.287885    0.018571  ...    1.351015
# 75%      0.003991    0.045475    0.399860    0.025784  ...    1.488878
# max      0.065199    0.192600    1.747600    0.113240  ...    1.860588
#
#            Delta4      Delta5      Delta6      Delta7      Delta8      Delta9  \
# count  240.000000  240.000000  240.000000  240.000000  240.000000  240.000000
# mean     1.348914    1.337717    1.341786    1.340895    1.343978    1.341472
# std      0.212008    0.204978    0.209407    0.213689    0.211364    0.204085
# min      0.840133    0.741690    0.759689    0.764649    0.762798    0.811942
# 25%      1.221101    1.197868    1.194186    1.194138    1.191881    1.189515
# 50%      1.342237    1.337233    1.338437    1.344416    1.335517    1.349243
# 75%      1.470287    1.485597    1.496845    1.490389    1.495355    1.475330
# max      2.038241    1.785984    1.988090    1.872799    1.920131    1.943331
#
#           Delta10     Delta11     Delta12
# count  240.000000  240.000000  240.000000
# mean     1.331433    1.346381    1.346144
# std      0.211297    0.221484    0.208819
# min      0.777012    0.643132    0.748411
# 25%      1.192397    1.202525    1.206559
# 50%      1.333345    1.347297    1.331212
# 75%      1.472589    1.506674    1.475235
# max      1.949679    1.918392    1.930103
#
# [8 rows x 47 columns]

# %%
data.corr()
# Out:
#             Recording    Status    Gender  Jitter_rel  Jitter_abs  Jitter_RAP  \
# Recording    1.000000  0.000000  0.000000   -0.044546   -0.044647   -0.049644
# Status       0.000000  1.000000 -0.102062    0.190406    0.096780    0.203766
# Gender       0.000000 -0.102062  1.000000   -0.135454   -0.271361   -0.087452
# Jitter_rel  -0.044546  0.190406 -0.135454    1.000000    0.959368    0.989639
# Jitter_abs  -0.044647  0.096780 -0.271361    0.959368    1.000000    0.933650
# Jitter_RAP  -0.049644  0.203766 -0.087452    0.989639    0.933650    1.000000
# Delta3      0.739098  0.744564  0.769232
# Delta4      0.690290  0.758201  0.824488
# Delta5      0.711204  0.678302  0.757014
# Delta6      0.721258  0.733984  0.831825
# Delta7      0.672991  0.704077  0.782252
# Delta8      0.810896  0.729327  0.788786
# Delta9      0.712780  0.754587  0.792959
# Delta10     1.000000  0.771750  0.770081
# Delta11     0.771750  1.000000  0.757428
# Delta12     0.770081  0.757428  1.000000
#
# [47 rows x 47 columns]

# %%
pd.plotting.scatter_matrix(data[['ID', 'Jitter_RAP', 'Shim_loc', 'Shim_APQ3', 'Delta3', 'Delta9', 'Delta11']], alpha=.01, figsize=(10, 10))
pass

# %%
pd.plotting.scatter_matrix(data[['Jitter_RAP', 'Shim_loc', 'Shim_APQ3', 'Delta3', 'Delta9', 'Delta11']], figsize=(10, 10))
pass

# %%
plt.plot(data['Shim_loc'], data['Delta9'], 'o')
plt.xlabel('Delta9')
plt.ylabel('Predicted spectral values (based on spatial interpolation) minus actual spectral values for the H class')
plt.title('Test')
pass

# %%
data['Jitter_rel']<0.27
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 235    False
# 236     True
# 237     True
# 238    False
# 239    False
# Name: Jitter_rel, Length: 240, dtype: bool

# %%
np.random.seed(0)
b1_rnd = data['Jitter_rel'] + np.random.rand(data.shape[0]) - .002

plt.figure(figsize = (20, 8))

plt.scatter(b1_rnd[data['Jitter_abs'] >= 1.35],
            data[data['Jitter_abs'] >= 1.25]['Delta4'],
            label = '>= 1.35',
            color = 'b')

plt.scatter(b1_rnd[data['Jitter_abs'] < 1.35],
            data[data['Jitter_abs'] < 1.25]['Delta4'],
            label = '< 1.35',
            color = 'r')

plt.xlabel('Jitter_rel')
plt.xticks(range(100))
plt.xlim(0, 100)
plt.ylabel('Jitter_abs')
plt.title('Test2')
plt.grid()

# %%
data.describe(include = ['object'])
# Out:
#              ID
# count       240
# unique       80
# top     PARK-32
# freq          3

# %%
data.describe(include = 'all')
# Out:
#              ID   Recording      Status      Gender  Jitter_rel  Jitter_abs  \
# count       240  240.000000  240.000000  240.000000  240.000000  240.000000
# unique       80         NaN         NaN         NaN         NaN         NaN
# top     PARK-32         NaN         NaN         NaN         NaN         NaN
# freq          3         NaN         NaN         NaN         NaN         NaN
# mean        NaN    2.000000    0.500000    0.400000    0.583987    0.000044
# std         NaN    0.818203    0.501045    0.490922    0.535769    0.000045
# min         NaN    1.000000    0.000000    0.000000    0.148010    0.000007
# 25%         NaN    1.000000    0.000000    0.000000    0.298260    0.000019
# 50%         NaN    2.000000    0.500000    0.000000    0.481455    0.000035
# 75%         NaN    3.000000    1.000000    1.000000    0.681685    0.000056
# max         NaN    3.000000    1.000000    1.000000    6.838200    0.000550
#
#         Jitter_RAP  Jitter_PPQ    Shim_loc     Shim_dB  ...      Delta3  \
# count   240.000000  240.000000  240.000000  240.000000  ...  240.000000
# unique         NaN         NaN         NaN         NaN  ...         NaN
# top            NaN         NaN         NaN         NaN  ...         NaN
# freq           NaN         NaN         NaN         NaN  ...         NaN
# mean      0.003172    0.003532    0.038428    0.336832  ...    1.343238
# std       0.003373    0.004449    0.023213    0.205905  ...    0.198174
# min       0.000678    0.001036    0.007444    0.064989  ...    0.766458
# 25%       0.001551    0.001867    0.024336    0.211785  ...    1.208624
# 50%       0.002337    0.002870    0.032960    0.287885  ...    1.351015
# 75%       0.003678    0.003991    0.045475    0.399860  ...    1.488878
# max       0.043843    0.065199    0.192600    1.747600  ...    1.860588
#
#             Delta4      Delta5      Delta6      Delta7      Delta8  \
# count   240.000000  240.000000  240.000000  240.000000  240.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean      1.348914    1.337717    1.341786    1.340895    1.343978
# std       0.212008    0.204978    0.209407    0.213689    0.211364
# min       0.840133    0.741690    0.759689    0.764649    0.762798
# 25%       1.221101    1.197868    1.194186    1.194138    1.191881
# 50%       1.342237    1.337233    1.338437    1.344416    1.335517
# 75%       1.470287    1.485597    1.496845    1.490389    1.495355
# max       2.038241    1.785984    1.988090    1.872799    1.920131
#
#             Delta9     Delta10     Delta11     Delta12
# count   240.000000  240.000000  240.000000  240.000000
# unique         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN
# mean      1.341472    1.331433    1.346381    1.346144
# std       0.204085    0.211297    0.221484    0.208819
# min       0.811942    0.777012    0.643132    0.748411
# 25%       1.189515    1.192397    1.202525    1.206559
# 50%       1.349243    1.333345    1.347297    1.331212
# 75%       1.475330    1.472589    1.506674    1.475235
# max       1.943331    1.949679    1.918392    1.930103
#
# [11 rows x 48 columns]

# %%
data['ID'].unique()
# Out:
# array(['CONT-01', 'CONT-02', 'CONT-03', 'CONT-04', 'CONT-05', 'CONT-06',
#        'CONT-07', 'CONT-08', 'CONT-09', 'CONT-10', 'CONT-11', 'CONT-12',
#        'CONT-13', 'CONT-14', 'CONT-15', 'CONT-16', 'CONT-17', 'CONT-18',
#        'CONT-19', 'CONT-20', 'CONT-21', 'CONT-22', 'CONT-23', 'CONT-24',
#        'CONT-25', 'CONT-26', 'CONT-27', 'CONT-28', 'CONT-29', 'CONT-30',
#        'CONT-31', 'CONT-32', 'CONT-33', 'CONT-34', 'CONT-35', 'CONT-36',
#        'CONT-37', 'CONT-38', 'CONT-39', 'CONT-40', 'PARK-01', 'PARK-02',
#        'PARK-03', 'PARK-04', 'PARK-05', 'PARK-06', 'PARK-07', 'PARK-08',
#        'PARK-09', 'PARK-10', 'PARK-11', 'PARK-12', 'PARK-13', 'PARK-14',
#        'PARK-15', 'PARK-16', 'PARK-17', 'PARK-18', 'PARK-19', 'PARK-20',
#        'PARK-21', 'PARK-22', 'PARK-23', 'PARK-24', 'PARK-25', 'PARK-26',
#        'PARK-27', 'PARK-28', 'PARK-29', 'PARK-30', 'PARK-31', 'PARK-32',
#        'PARK-33', 'PARK-34', 'PARK-35', 'PARK-36', 'PARK-37', 'PARK-38',
#        'PARK-39', 'PARK-40'], dtype=object)

# %%
data['Recording'].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# ['ID']
# ['Recording', 'Status', 'Gender', 'Jitter_rel', 'Jitter_abs', 'Jitter_RAP', 'Jitter_PPQ', 'Shim_loc', 'Shim_dB', 'Shim_APQ3', 'Shim_APQ5', 'Shi_APQ11', 'HNR05', 'HNR15', 'HNR25', 'HNR35', 'HNR38', 'RPDE', 'DFA', 'PPE', 'GNE', 'MFCC0', 'MFCC1', 'MFCC2', 'MFCC3', 'MFCC4', 'MFCC5', 'MFCC6', 'MFCC7', 'MFCC8', 'MFCC9', 'MFCC10', 'MFCC11', 'MFCC12', 'Delta0', 'Delta1', 'Delta2', 'Delta3', 'Delta4', 'Delta5', 'Delta6', 'Delta7', 'Delta8', 'Delta9', 'Delta10', 'Delta11', 'Delta12']

# %%
for c in categorical_columns:
    print(c, data[c].unique())
# Out:
# ID ['CONT-01' 'CONT-02' 'CONT-03' 'CONT-04' 'CONT-05' 'CONT-06' 'CONT-07'
#  'CONT-08' 'CONT-09' 'CONT-10' 'CONT-11' 'CONT-12' 'CONT-13' 'CONT-14'
#  'CONT-15' 'CONT-16' 'CONT-17' 'CONT-18' 'CONT-19' 'CONT-20' 'CONT-21'
#  'CONT-22' 'CONT-23' 'CONT-24' 'CONT-25' 'CONT-26' 'CONT-27' 'CONT-28'
#  'CONT-29' 'CONT-30' 'CONT-31' 'CONT-32' 'CONT-33' 'CONT-34' 'CONT-35'
#  'CONT-36' 'CONT-37' 'CONT-38' 'CONT-39' 'CONT-40' 'PARK-01' 'PARK-02'
#  'PARK-03' 'PARK-04' 'PARK-05' 'PARK-06' 'PARK-07' 'PARK-08' 'PARK-09'
#  'PARK-10' 'PARK-11' 'PARK-12' 'PARK-13' 'PARK-14' 'PARK-15' 'PARK-16'
#  'PARK-17' 'PARK-18' 'PARK-19' 'PARK-20' 'PARK-21' 'PARK-22' 'PARK-23'
#  'PARK-24' 'PARK-25' 'PARK-26' 'PARK-27' 'PARK-28' 'PARK-29' 'PARK-30'
#  'PARK-31' 'PARK-32' 'PARK-33' 'PARK-34' 'PARK-35' 'PARK-36' 'PARK-37'
#  'PARK-38' 'PARK-39' 'PARK-40']

# %%
data.median(axis = 0)
# Out:
# Recording      2.000000
# Status         0.500000
# Gender         0.000000
# Jitter_rel     0.481455
# Jitter_abs     0.000035
# Jitter_RAP     0.002337
# Jitter_PPQ     0.002870
# Shim_loc       0.032960
# Shim_dB        0.287885
# Shim_APQ3      0.018571
# Shim_APQ5      0.019897
# Shi_APQ11      0.024909
# HNR05         59.742330
# HNR15         64.844019
# HNR25         75.457858
# HNR35         80.992704
# HNR38         82.354119
# RPDE           0.305054
# DFA            0.606502
# PPE            0.246486
# GNE            0.912809
# MFCC0          1.340906
# MFCC1          1.294779
# MFCC2          1.298645
# MFCC3          1.338791
# MFCC4          1.342907
# MFCC5          1.331794
# MFCC6          1.323245
# MFCC7          1.321939
# MFCC8          1.340258
# MFCC9          1.334706
# MFCC10         1.338213
# MFCC11         1.356528
# MFCC12         1.338452
# Delta0         1.333607
# Delta1         1.341507
# Delta2         1.323866
# Delta3         1.351015
# Delta4         1.342237
# Delta5         1.337233
# Delta6         1.338437
# Delta7         1.344416
# Delta8         1.335517
# Delta9         1.349243
# Delta10        1.333345
# Delta11        1.347297
# Delta12        1.331212
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
data_describe = data.describe(include = [object])
for c in categorical_columns:
    data[c] = data[c].fillna(data_describe[c]['top'])

# %%
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
print(binary_columns, nonbinary_columns)
# Out:
# [] ['ID']

# %%
data_nonbinary = pd.get_dummies(data[nonbinary_columns])
print(data_nonbinary.columns)
# Out:
# Index(['ID_CONT-01', 'ID_CONT-02', 'ID_CONT-03', 'ID_CONT-04', 'ID_CONT-05',
#        'ID_CONT-06', 'ID_CONT-07', 'ID_CONT-08', 'ID_CONT-09', 'ID_CONT-10',
#        'ID_CONT-11', 'ID_CONT-12', 'ID_CONT-13', 'ID_CONT-14', 'ID_CONT-15',
#        'ID_CONT-16', 'ID_CONT-17', 'ID_CONT-18', 'ID_CONT-19', 'ID_CONT-20',
#        'ID_CONT-21', 'ID_CONT-22', 'ID_CONT-23', 'ID_CONT-24', 'ID_CONT-25',
#        'ID_CONT-26', 'ID_CONT-27', 'ID_CONT-28', 'ID_CONT-29', 'ID_CONT-30',
#        'ID_CONT-31', 'ID_CONT-32', 'ID_CONT-33', 'ID_CONT-34', 'ID_CONT-35',
#        'ID_CONT-36', 'ID_CONT-37', 'ID_CONT-38', 'ID_CONT-39', 'ID_CONT-40',
#        'ID_PARK-01', 'ID_PARK-02', 'ID_PARK-03', 'ID_PARK-04', 'ID_PARK-05',
#        'ID_PARK-06', 'ID_PARK-07', 'ID_PARK-08', 'ID_PARK-09', 'ID_PARK-10',
#        'ID_PARK-11', 'ID_PARK-12', 'ID_PARK-13', 'ID_PARK-14', 'ID_PARK-15',
#        'ID_PARK-16', 'ID_PARK-17', 'ID_PARK-18', 'ID_PARK-19', 'ID_PARK-20',
#        'ID_PARK-21', 'ID_PARK-22', 'ID_PARK-23', 'ID_PARK-24', 'ID_PARK-25',
#        'ID_PARK-26', 'ID_PARK-27', 'ID_PARK-28', 'ID_PARK-29', 'ID_PARK-30',
#        'ID_PARK-31', 'ID_PARK-32', 'ID_PARK-33', 'ID_PARK-34', 'ID_PARK-35',
#        'ID_PARK-36', 'ID_PARK-37', 'ID_PARK-38', 'ID_PARK-39', 'ID_PARK-40'],
#       dtype='object')

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#         Recording      Status      Gender  Jitter_rel  Jitter_abs  Jitter_RAP  \
# count  240.000000  240.000000  240.000000  240.000000  240.000000  240.000000
# mean     2.000000    0.500000    0.400000    0.583987    0.000044    0.003172
# std      0.818203    0.501045    0.490922    0.535769    0.000045    0.003373
# min      1.000000    0.000000    0.000000    0.148010    0.000007    0.000678
# 25%      1.000000    0.000000    0.000000    0.298260    0.000019    0.001551
# 50%      2.000000    0.500000    0.000000    0.481455    0.000035    0.002337
# 75%      3.000000    1.000000    1.000000    0.681685    0.000056    0.003678
# max      3.000000    1.000000    1.000000    6.838200    0.000550    0.043843
#
#        Jitter_PPQ    Shim_loc     Shim_dB   Shim_APQ3  ...      Delta3  \
# count  240.000000  240.000000  240.000000  240.000000  ...  240.000000
# mean     0.003532    0.038428    0.336832    0.021499  ...    1.343238
# std      0.004449    0.023213    0.205905    0.013787  ...    0.198174
# min      0.001036    0.007444    0.064989    0.003344  ...    0.766458
# 25%      0.001867    0.024336    0.211785    0.012909  ...    1.208624
# 50%      0.002870    0.032960    0.287885    0.018571  ...    1.351015
# 75%      0.003991    0.045475    0.399860    0.025784  ...    1.488878
# max      0.065199    0.192600    1.747600    0.113240  ...    1.860588
#
#            Delta4      Delta5      Delta6      Delta7      Delta8      Delta9  \
# count  240.000000  240.000000  240.000000  240.000000  240.000000  240.000000
# mean     1.348914    1.337717    1.341786    1.340895    1.343978    1.341472
# std      0.212008    0.204978    0.209407    0.213689    0.211364    0.204085
# min      0.840133    0.741690    0.759689    0.764649    0.762798    0.811942
# 25%      1.221101    1.197868    1.194186    1.194138    1.191881    1.189515
# 50%      1.342237    1.337233    1.338437    1.344416    1.335517    1.349243
# 75%      1.470287    1.485597    1.496845    1.490389    1.495355    1.475330
# max      2.038241    1.785984    1.988090    1.872799    1.920131    1.943331
#
#           Delta10     Delta11     Delta12
# count  240.000000  240.000000  240.000000
# mean     1.331433    1.346381    1.346144
# std      0.211297    0.221484    0.208819
# min      0.777012    0.643132    0.748411
# 25%      1.192397    1.202525    1.206559
# 50%      1.333345    1.347297    1.331212
# 75%      1.472589    1.506674    1.475235
# max      1.949679    1.918392    1.930103
#
# [8 rows x 47 columns]

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)

# %%
data_numerical.describe()
# Out:
#         Recording        Status        Gender    Jitter_rel    Jitter_abs  \
# count  240.000000  2.400000e+02  2.400000e+02  2.400000e+02  2.400000e+02
# mean     0.000000  1.757853e-17 -2.923587e-16 -1.348458e-16 -9.166279e-16
# std      1.000000  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min     -1.222191 -9.979145e-01 -8.147938e-01 -8.137408e-01 -8.277442e-01
# 25%     -1.222191 -9.979145e-01 -8.147938e-01 -5.333027e-01 -5.567426e-01
# 50%      0.000000  0.000000e+00 -8.147938e-01 -1.913734e-01 -2.022649e-01
# 75%      1.222191  9.979145e-01  1.222191e+00  1.823513e-01  2.599288e-01
# max      1.222191  9.979145e-01  1.222191e+00  1.167334e+01  1.117968e+01
#
#          Jitter_RAP    Jitter_PPQ      Shim_loc       Shim_dB     Shim_APQ3  \
# count  2.400000e+02  2.400000e+02  2.400000e+02  2.400000e+02  2.400000e+02
# mean   1.378527e-16 -1.591320e-16 -1.057487e-15 -8.655114e-16 -3.594347e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -7.394552e-01 -5.609309e-01 -1.334779e+00 -1.320239e+00 -1.316901e+00
# 25%   -4.808223e-01 -3.742016e-01 -6.070989e-01 -6.073064e-01 -6.230575e-01
# 50%   -2.478066e-01 -1.488050e-01 -2.355880e-01 -2.377176e-01 -2.123754e-01
# 75%    1.500680e-01  1.031397e-01  3.035608e-01  3.061024e-01  3.107511e-01
# max    1.205868e+01  1.385942e+01  6.641621e+00  6.851563e+00  6.654220e+00
#
#        ...        Delta3        Delta4        Delta5        Delta6  \
# count  ...  2.400000e+02  2.400000e+02  2.400000e+02  2.400000e+02
# mean   ... -1.448610e-15 -2.176731e-15 -8.266536e-16  7.004582e-15
# std    ...  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min    ... -2.910464e+00 -2.399818e+00 -2.907766e+00 -2.779740e+00
# 25%    ... -6.792673e-01 -6.028685e-01 -6.822631e-01 -7.048458e-01
# 50%    ...  3.924693e-02 -3.149149e-02 -2.363688e-03 -1.598974e-02
# 75%    ...  7.349103e-01  5.724904e-01  7.214435e-01  7.404679e-01
# max    ...  2.610582e+00  3.251417e+00  2.186905e+00  3.086357e+00
#
#              Delta7        Delta8        Delta9       Delta10       Delta11  \
# count  2.400000e+02  2.400000e+02  2.400000e+02  2.400000e+02  2.400000e+02
# mean   3.901277e-15 -2.434627e-15  2.051600e-16 -4.107131e-15  5.478257e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.696655e+00 -2.749668e+00 -2.594660e+00 -2.623901e+00 -3.175166e+00
# 25%   -6.867785e-01 -7.195960e-01 -7.445795e-01 -6.580137e-01 -6.495114e-01
# 50%    1.647671e-02 -4.002655e-02  3.807477e-02  9.046775e-03  4.136121e-03
# 75%    6.995879e-01  7.161937e-01  6.558936e-01  6.680464e-01  7.237209e-01
# max    2.489147e+00  2.725888e+00  2.949068e+00  2.925960e+00  2.582626e+00
#
#             Delta12
# count  2.400000e+02
# mean   6.133982e-16
# std    1.000000e+00
# min   -2.862447e+00
# 25%   -6.684506e-01
# 50%   -7.150982e-02
# 75%    6.181964e-01
# max    2.796483e+00
#
# [8 rows x 47 columns]

# %%
data = pd.concat((data_numerical, data_nonbinary, data[binary_columns]), axis = 1)
print(data.shape)
# Out:
# (240, 127)

# %%
data.describe()
# Out:
#         Recording        Status        Gender    Jitter_rel    Jitter_abs  \
# count  240.000000  2.400000e+02  2.400000e+02  2.400000e+02  2.400000e+02
# mean     0.000000  1.757853e-17 -2.923587e-16 -1.348458e-16 -9.166279e-16
# std      1.000000  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min     -1.222191 -9.979145e-01 -8.147938e-01 -8.137408e-01 -8.277442e-01
# 25%     -1.222191 -9.979145e-01 -8.147938e-01 -5.333027e-01 -5.567426e-01
# 50%      0.000000  0.000000e+00 -8.147938e-01 -1.913734e-01 -2.022649e-01
# 75%      1.222191  9.979145e-01  1.222191e+00  1.823513e-01  2.599288e-01
# max      1.222191  9.979145e-01  1.222191e+00  1.167334e+01  1.117968e+01
#
#          Jitter_RAP    Jitter_PPQ      Shim_loc       Shim_dB     Shim_APQ3  \
# count  2.400000e+02  2.400000e+02  2.400000e+02  2.400000e+02  2.400000e+02
# mean   1.378527e-16 -1.591320e-16 -1.057487e-15 -8.655114e-16 -3.594347e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -7.394552e-01 -5.609309e-01 -1.334779e+00 -1.320239e+00 -1.316901e+00
# 25%   -4.808223e-01 -3.742016e-01 -6.070989e-01 -6.073064e-01 -6.230575e-01
# 50%   -2.478066e-01 -1.488050e-01 -2.355880e-01 -2.377176e-01 -2.123754e-01
# 75%    1.500680e-01  1.031397e-01  3.035608e-01  3.061024e-01  3.107511e-01
# max    1.205868e+01  1.385942e+01  6.641621e+00  6.851563e+00  6.654220e+00
#
#        ...  ID_PARK-31  ID_PARK-32  ID_PARK-33  ID_PARK-34  ID_PARK-35  \
# count  ...  240.000000  240.000000  240.000000  240.000000  240.000000
# mean   ...    0.012500    0.012500    0.012500    0.012500    0.012500
# std    ...    0.111335    0.111335    0.111335    0.111335    0.111335
# min    ...    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    ...    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%    ...    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%    ...    0.000000    0.000000    0.000000    0.000000    0.000000
# max    ...    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        ID_PARK-36  ID_PARK-37  ID_PARK-38  ID_PARK-39  ID_PARK-40
# count  240.000000  240.000000  240.000000  240.000000  240.000000
# mean     0.012500    0.012500    0.012500    0.012500    0.012500
# std      0.111335    0.111335    0.111335    0.111335    0.111335
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 127 columns]

# %%
X = data.drop(('Recording'), axis = 1)
y = data['Recording']
feature_names = X.columns

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (240, 126)
# (240,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 168 72

# %%
from sklearn import utils

print(utils.multiclass.type_of_target(y_train))
print(utils.multiclass.type_of_target(y_train.astype('int')))
# Out:
# continuous
# multiclass

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 5)
#knn.set_params(n_neighbors=10)
knn.fit(X_train, y_train.astype('int'))
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train.astype('int') != y_train_predict)
err_test  = np.mean(y_test.astype('int')  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.5297619047619048 0.8333333333333334

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train.astype('int'))

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.6726190476190477 55
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train.astype('int'))

err_train = np.mean(y_train.astype('int') != knn.predict(X_train))
err_test  = np.mean(y_test.astype('int')  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.6369047619047619 0.7638888888888888

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train.astype('int'))

err_train = np.mean(y_train.astype('int') != rf.predict(X_train))
err_test  = np.mean(y_test.astype('int')  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.005952380952380952 0.875

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
#  1. feature 'MFCC9' (0.028736)
#  2. feature 'MFCC5' (0.027644)
#  3. feature '  GNE' (0.027307)
#  4. feature 'Delta10' (0.026430)
#  5. feature 'Delta7' (0.025852)
#  6. feature 'Delta3' (0.025832)
#  7. feature 'Delta5' (0.024864)
#  8. feature 'MFCC11' (0.024834)
#  9. feature 'HNR15' (0.023368)
# 10. feature 'Delta9' (0.023266)
# 11. feature 'MFCC3' (0.023144)
# 12. feature 'Delta8' (0.022962)
# 13. feature 'Delta12' (0.022900)
# 14. feature 'Delta6' (0.022793)
# 15. feature 'MFCC1' (0.022765)
# 16. feature ' RPDE' (0.022735)
# 17. feature 'HNR35' (0.022175)
# 18. feature 'MFCC2' (0.022110)
# 19. feature 'Jitter_PPQ' (0.022025)
# 20. feature 'HNR38' (0.021754)
# 21. feature '  DFA' (0.021560)
# 22. feature '  PPE' (0.021512)
# 23. feature 'Delta0' (0.021429)
# 24. feature 'MFCC8' (0.021359)
# 25. feature 'Jitter_abs' (0.021264)
# 26. feature 'Delta2' (0.021148)
# 27. feature 'MFCC7' (0.021108)
# 28. feature 'HNR25' (0.020916)
# 29. feature 'MFCC0' (0.020684)
# 30. feature 'Jitter_RAP' (0.020667)
# 31. feature 'MFCC10' (0.020586)
# 32. feature 'Delta11' (0.020264)
# 33. feature 'MFCC6' (0.020257)
# 34. feature 'Shim_APQ3' (0.020226)
# 35. feature 'Delta4' (0.020182)
# 36. feature 'Jitter_rel' (0.020062)
# 37. feature 'Delta1' (0.019716)
# 38. feature 'HNR05' (0.019424)
# 39. feature 'Shim_APQ5' (0.019145)
# 40. feature 'MFCC4' (0.019134)
# 41. feature 'Shim_loc' (0.018721)
# 42. feature 'Shim_dB' (0.018664)
# 43. feature 'Shi_APQ11' (0.018493)
# 44. feature 'MFCC12' (0.017843)
# 45. feature 'Status' (0.003225)
# 46. feature 'Gender' (0.002634)
# 47. feature 'ID_CONT-14' (0.000928)
# 48. feature 'ID_PARK-09' (0.000877)
# 49. feature 'ID_CONT-17' (0.000673)
# 50. feature 'ID_PARK-10' (0.000650)
# 51. feature 'ID_PARK-33' (0.000623)
# 52. feature 'ID_CONT-08' (0.000612)
# 53. feature 'ID_CONT-20' (0.000612)
# 54. feature 'ID_PARK-05' (0.000611)
# 55. feature 'ID_PARK-24' (0.000576)
# 56. feature 'ID_CONT-12' (0.000559)
# 57. feature 'ID_PARK-18' (0.000541)
# 58. feature 'ID_PARK-38' (0.000540)
# 59. feature 'ID_PARK-04' (0.000509)
# 60. feature 'ID_PARK-16' (0.000498)
# 61. feature 'ID_PARK-32' (0.000466)
# 62. feature 'ID_CONT-25' (0.000453)
# 63. feature 'ID_CONT-22' (0.000446)
# 64. feature 'ID_PARK-15' (0.000443)
# 65. feature 'ID_CONT-05' (0.000441)
# 66. feature 'ID_PARK-26' (0.000412)
# 67. feature 'ID_PARK-40' (0.000409)
# 68. feature 'ID_CONT-35' (0.000405)
# 69. feature 'ID_CONT-19' (0.000397)
# 70. feature 'ID_CONT-15' (0.000395)
# 71. feature 'ID_PARK-07' (0.000392)
# 72. feature 'ID_CONT-28' (0.000377)
# 73. feature 'ID_PARK-08' (0.000374)
# 74. feature 'ID_CONT-30' (0.000373)
# 75. feature 'ID_CONT-01' (0.000373)
# 76. feature 'ID_PARK-27' (0.000369)
# 77. feature 'ID_PARK-21' (0.000368)
# 78. feature 'ID_CONT-27' (0.000355)
# 79. feature 'ID_CONT-03' (0.000350)
# 80. feature 'ID_CONT-33' (0.000340)
# 81. feature 'ID_PARK-36' (0.000329)
# 82. feature 'ID_CONT-34' (0.000328)
# 83. feature 'ID_CONT-10' (0.000327)
# 84. feature 'ID_CONT-40' (0.000324)
# 85. feature 'ID_PARK-14' (0.000322)
# 86. feature 'ID_CONT-13' (0.000320)
# 87. feature 'ID_PARK-22' (0.000311)
# 88. feature 'ID_PARK-28' (0.000306)
# 89. feature 'ID_PARK-31' (0.000305)
# 90. feature 'ID_PARK-01' (0.000302)
# 91. feature 'ID_PARK-23' (0.000294)
# 92. feature 'ID_CONT-31' (0.000293)
# 93. feature 'ID_CONT-02' (0.000286)
# 94. feature 'ID_PARK-20' (0.000278)
# 95. feature 'ID_CONT-26' (0.000272)
# 96. feature 'ID_CONT-16' (0.000266)
# 97. feature 'ID_PARK-37' (0.000265)
# 98. feature 'ID_CONT-36' (0.000261)
# 99. feature 'ID_PARK-11' (0.000257)
# 100. feature 'ID_PARK-13' (0.000244)
# 101. feature 'ID_CONT-24' (0.000244)
# 102. feature 'ID_CONT-32' (0.000243)
# 103. feature 'ID_PARK-35' (0.000237)
# 104. feature 'ID_PARK-12' (0.000231)
# 105. feature 'ID_PARK-29' (0.000218)
# 106. feature 'ID_PARK-39' (0.000211)
# 107. feature 'ID_CONT-11' (0.000201)
# 108. feature 'ID_CONT-18' (0.000198)
# 109. feature 'ID_PARK-03' (0.000197)
# 110. feature 'ID_CONT-09' (0.000195)
# 111. feature 'ID_PARK-17' (0.000193)
# 112. feature 'ID_PARK-19' (0.000192)
# 113. feature 'ID_PARK-02' (0.000189)
# 114. feature 'ID_PARK-34' (0.000145)
# 115. feature 'ID_CONT-21' (0.000132)
# 116. feature 'ID_CONT-07' (0.000124)
# 117. feature 'ID_PARK-06' (0.000118)
# 118. feature 'ID_CONT-29' (0.000111)
# 119. feature 'ID_CONT-06' (0.000084)
# 120. feature 'ID_PARK-30' (0.000075)
# 121. feature 'ID_CONT-39' (0.000066)
# 122. feature 'ID_CONT-37' (0.000026)
# 123. feature 'ID_CONT-04' (0.000014)
# 124. feature 'ID_PARK-25' (0.000000)
# 125. feature 'ID_CONT-38' (0.000000)
# 126. feature 'ID_CONT-23' (0.000000)

# %%
np.sum(rf.feature_importances_)
# Out:
# 1.0000000000000002

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
#  1. feature 'MFCC9' (0.028736)
#  2. feature 'MFCC5' (0.027644)
#  3. feature '  GNE' (0.027307)
#  4. feature 'Delta10' (0.026430)
#  5. feature 'Delta7' (0.025852)
#  6. feature 'Delta3' (0.025832)
#  7. feature 'Delta5' (0.024864)
#  8. feature 'MFCC11' (0.024834)
#  9. feature 'HNR15' (0.023368)
# 10. feature 'Delta9' (0.023266)
# 11. feature 'MFCC3' (0.023144)
# 12. feature 'Delta8' (0.022962)
# 13. feature 'Delta12' (0.022900)
# 14. feature 'Delta6' (0.022793)
# 15. feature 'MFCC1' (0.022765)
# 16. feature ' RPDE' (0.022735)
# 17. feature 'HNR35' (0.022175)
# 18. feature 'MFCC2' (0.022110)
# 19. feature 'Jitter_PPQ' (0.022025)
# 20. feature 'HNR38' (0.021754)
# 21. feature '  DFA' (0.021560)
# 22. feature '  PPE' (0.021512)
# 23. feature 'Delta0' (0.021429)
# 24. feature 'MFCC8' (0.021359)
# 25. feature 'Jitter_abs' (0.021264)
# 26. feature 'Delta2' (0.021148)
# 27. feature 'MFCC7' (0.021108)
# 28. feature 'HNR25' (0.020916)
# 29. feature 'MFCC0' (0.020684)
# 30. feature 'Jitter_RAP' (0.020667)
# 31. feature 'MFCC10' (0.020586)
# 32. feature 'Delta11' (0.020264)
# 33. feature 'MFCC6' (0.020257)
# 34. feature 'Shim_APQ3' (0.020226)
# 35. feature 'Delta4' (0.020182)
# 36. feature 'Jitter_rel' (0.020062)
# 37. feature 'Delta1' (0.019716)
# 38. feature 'HNR05' (0.019424)
# 39. feature 'Shim_APQ5' (0.019145)
# 40. feature 'MFCC4' (0.019134)
# 41. feature 'Shim_loc' (0.018721)
# 42. feature 'Shim_dB' (0.018664)
# 43. feature 'Shi_APQ11' (0.018493)
# 44. feature 'MFCC12' (0.017843)
# 45. feature 'Status' (0.003225)
# 46. feature 'Gender' (0.002634)
# 47. feature 'ID_CONT-14' (0.000928)
# 48. feature 'ID_PARK-09' (0.000877)
# 49. feature 'ID_CONT-17' (0.000673)
# 50. feature 'ID_PARK-10' (0.000650)
# 51. feature 'ID_PARK-33' (0.000623)
# 52. feature 'ID_CONT-08' (0.000612)
# 53. feature 'ID_CONT-20' (0.000612)
# 54. feature 'ID_PARK-05' (0.000611)
# 55. feature 'ID_PARK-24' (0.000576)
# 56. feature 'ID_CONT-12' (0.000559)
# 57. feature 'ID_PARK-18' (0.000541)
# 58. feature 'ID_PARK-38' (0.000540)
# 59. feature 'ID_PARK-04' (0.000509)
# 60. feature 'ID_PARK-16' (0.000498)
# 61. feature 'ID_PARK-32' (0.000466)
# 62. feature 'ID_CONT-25' (0.000453)
# 63. feature 'ID_CONT-22' (0.000446)
# 64. feature 'ID_PARK-15' (0.000443)
# 65. feature 'ID_CONT-05' (0.000441)
# 66. feature 'ID_PARK-26' (0.000412)
# 67. feature 'ID_PARK-40' (0.000409)
# 68. feature 'ID_CONT-35' (0.000405)
# 69. feature 'ID_CONT-19' (0.000397)
# 70. feature 'ID_CONT-15' (0.000395)
# 71. feature 'ID_PARK-07' (0.000392)
# 72. feature 'ID_CONT-28' (0.000377)
# 73. feature 'ID_PARK-08' (0.000374)
# 74. feature 'ID_CONT-30' (0.000373)
# 75. feature 'ID_CONT-01' (0.000373)
# 76. feature 'ID_PARK-27' (0.000369)
# 77. feature 'ID_PARK-21' (0.000368)
# 78. feature 'ID_CONT-27' (0.000355)
# 79. feature 'ID_CONT-03' (0.000350)
# 80. feature 'ID_CONT-33' (0.000340)
# 81. feature 'ID_PARK-36' (0.000329)
# 82. feature 'ID_CONT-34' (0.000328)
# 83. feature 'ID_CONT-10' (0.000327)
# 84. feature 'ID_CONT-40' (0.000324)
# 85. feature 'ID_PARK-14' (0.000322)
# 86. feature 'ID_CONT-13' (0.000320)
# 87. feature 'ID_PARK-22' (0.000311)
# 88. feature 'ID_PARK-28' (0.000306)
# 89. feature 'ID_PARK-31' (0.000305)
# 90. feature 'ID_PARK-01' (0.000302)
# 91. feature 'ID_PARK-23' (0.000294)
# 92. feature 'ID_CONT-31' (0.000293)
# 93. feature 'ID_CONT-02' (0.000286)
# 94. feature 'ID_PARK-20' (0.000278)
# 95. feature 'ID_CONT-26' (0.000272)
# 96. feature 'ID_CONT-16' (0.000266)
# 97. feature 'ID_PARK-37' (0.000265)
# 98. feature 'ID_CONT-36' (0.000261)
# 99. feature 'ID_PARK-11' (0.000257)
# 100. feature 'ID_PARK-13' (0.000244)
# 101. feature 'ID_CONT-24' (0.000244)
# 102. feature 'ID_CONT-32' (0.000243)
# 103. feature 'ID_PARK-35' (0.000237)
# 104. feature 'ID_PARK-12' (0.000231)
# 105. feature 'ID_PARK-29' (0.000218)
# 106. feature 'ID_PARK-39' (0.000211)
# 107. feature 'ID_CONT-11' (0.000201)
# 108. feature 'ID_CONT-18' (0.000198)
# 109. feature 'ID_PARK-03' (0.000197)
# 110. feature 'ID_CONT-09' (0.000195)
# 111. feature 'ID_PARK-17' (0.000193)
# 112. feature 'ID_PARK-19' (0.000192)
# 113. feature 'ID_PARK-02' (0.000189)
# 114. feature 'ID_PARK-34' (0.000145)
# 115. feature 'ID_CONT-21' (0.000132)
# 116. feature 'ID_CONT-07' (0.000124)
# 117. feature 'ID_PARK-06' (0.000118)
# 118. feature 'ID_CONT-29' (0.000111)
# 119. feature 'ID_CONT-06' (0.000084)
# 120. feature 'ID_PARK-30' (0.000075)
# 121. feature 'ID_CONT-39' (0.000066)
# 122. feature 'ID_CONT-37' (0.000026)
# 123. feature 'ID_CONT-04' (0.000014)
# 124. feature 'ID_PARK-25' (0.000000)
# 125. feature 'ID_CONT-38' (0.000000)
# 126. feature 'ID_CONT-23' (0.000000)

# %%
feature_names[[1,0,1]]
# Out:
# Index(['Gender', 'Status', 'Gender'], dtype='object')

# %%
d_first = 20
plt.title("Feature importances")
plt.bar(range(d_first), importances[indices[:d_first]], align = 'center', color = 'r')
plt.xticks(range(d_first), feature_names[indices[:d_first]], rotation = 90)
plt.xlim([-1, d_first])
# Out:
# (-1, 20)

# %%
ert = ensemble.ExtraTreesClassifier(n_estimators = 100).fit(X_train, y_train.astype('int'))

err_train = np.mean(y_train.astype('int') != ert.predict(X_train))
err_test  = np.mean(y_test.astype('int')  != ert.predict(X_test))

print(err_train, err_test)
# Out:
# 0.005952380952380952 0.9166666666666666

# %%
ada = ensemble.AdaBoostClassifier(n_estimators = 1000)
ada.fit(X_train, y_train.astype('int'))

err_train = np.mean(y_train.astype('int') != ada.predict(X_train))
err_test = np.mean(y_test.astype('int') != ada.predict(X_test))

print(err_train, err_test)
# Out:
# 0.05357142857142857 0.7361111111111112

# %%
gbt = ensemble.GradientBoostingClassifier(n_estimators = 1000)
gbt.fit(X_train, y_train.astype('int'))

err_train = np.mean(y_train.astype('int') != gbt.predict(X_train))
err_test = np.mean(y_test.astype('int') != gbt.predict(X_test))

print(err_train, err_test)
# Out:
# 0.005952380952380952 0.7361111111111112

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
X_train_PCA = pca.fit_transform(X_train)

# %%
plt.plot(X_train_PCA[0], X_train_PCA[1], 'o')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Test')
# Out:
# Text(0.5, 1.0, 'Test')

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.54002004 0.13268446]

# %%
print(pca.singular_values_)
# Out:
# [62.26560579 30.86407827]

# %%
error_values = {}
for i in range(2,27,1):
    pca_train = PCA(n_components=i)

    X_train_PCA = pca_train.fit_transform(X_train)
    X_test_PCA = pca_train.fit_transform(X_test) 
    
    knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train_PCA, y_train.astype('int'))

    err_train = np.mean(y_train.astype('int') != knn.predict(X_train_PCA))
    err_test  = np.mean(y_test.astype('int')  != knn.predict(X_test_PCA))
    error_values[i]=[err_train, err_test]

# %%
X_values = [item for item in error_values.keys()]
Y_values = [item[0] for item in error_values.values()]
Y_values_test = [item[1] for item in error_values.values()]
plt.plot(X_values, Y_values)
plt.plot(X_values, Y_values_test)
plt.xlabel('Number of PCA')
plt.ylabel('Error')
plt.title('Test')
# Out:
# Text(0.5, 1.0, 'Test')

# %%
# Следует выделить, что наименьшая ошибка на тестовой выборке достигается при числе главных компонент = 6
# Свыше 6 главных компонент ошибка перестает изменяться
print(error_values[6])
print(error_values[7])
print(error_values[8])
# Out:
# [0.6130952380952381, 0.6666666666666666]
# [0.5833333333333334, 0.6944444444444444]
# [0.6011904761904762, 0.7638888888888888]

# %%
# В данном случае PCA позволяет снизить ошибку на тестовой выборке по сравнению с другими методами

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 7)
N_test, _ = X_test.shape
y_train = y_train.astype("int")
y_test = y_test.astype("int")

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (2,), solver = 'lbfgs', 
                          activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(2,), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=42, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

# %%
# Ошибка на тестовой и обучающей выборке
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.21875 0.7875

# %%
print(mlp_model.score(X_train, y_train), mlp_model.score(X_test, y_test))
# Out:
# 0.78125 0.2125

# %%
print(1 - mlp_model.score(X_test, y_test))
# Out:
# 0.7875

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test_pred, y_test))
# Out:
# [[ 4 11 12]
#  [12  7  6]
#  [14  8  6]]

# %%
M = confusion_matrix(y_test_pred, y_test)
M = np.sqrt(M)
plt.imshow(M, interpolation = 'nearest')
plt.set_cmap('binary')
plt.xticks(range(3))
plt.yticks(range(3))
plt.xlabel("true label")
plt.ylabel("predicted label")
plt.colorbar()
pass

# %%
alpha_arr = np.logspace(-3, 2, 21)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = (2,), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.semilogx(alpha_arr, train_err, 'b-o', label = 'train')
plt.semilogx(alpha_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.max(alpha_arr), np.min(alpha_arr)])
plt.title('Error vs. alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)

# При alpha < 2 наблюдается переобучение алгоритма, величина ошибки на тестовой выборке оказывается выше 
# ошибки на обучающей выборке
# Out:
# 0.11875 0.6625

# %%
alpha_opt = alpha_arr[test_err == min_test_err]
print(alpha_opt)
# Out:
# [3.16227766]

# %%
alpha_opt = alpha_opt[0]

# %%
mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (2,),
                          solver = 'lbfgs', activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)

y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)
print(np.mean(y_train != y_train_pred))
print(np.mean(y_test != y_test_pred))
# Out:
# 0.39375
# 0.6625

# %%
layer_sizes_arr = np.arange(2, 40, 1)
test_err = []
train_err = []
for layer_sizes in layer_sizes_arr:
    mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (layer_sizes,), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.plot(layer_sizes_arr, train_err, 'b-o', label = 'train')
plt.plot(layer_sizes_arr, test_err, 'r-o', label = 'test')
#plt.xlim([np.max(layer_sizes_arr), np.min(layer_sizes_arr)])
plt.title('Error vs. number of neurons')
plt.xlabel('Number of neurons')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)

layer_opt = layer_sizes_arr[test_err == min_test_err]
print("Оптимальное число нейронов:{}".format(layer_opt))

# Переобучения не наблюдается
# Out:
# 0.39375 0.6625
# Оптимальное число нейронов:[2 3]

# %%
from sklearn.ensemble import RandomForestClassifier
RFC = RandomForestClassifier(n_estimators=100, random_state=42, oob_score=True)
RFC.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=True, random_state=42, verbose=0,
#                        warm_start=False)

# %%
y_train_pred = RFC.predict(X_train)
y_test_pred = RFC.predict(X_test)

# %%
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.00625 0.7125

# %%
tree_arr = np.arange(16, 101, 5)
test_err = []
train_err = []
oob_err = []
RFC = RandomForestClassifier(warm_start=True, n_estimators=1, random_state=42, oob_score=True)
for tree in tree_arr:
    RFC.set_params(n_estimators=tree)
    RFC.fit(X_train, y_train)

    y_train_pred = RFC.predict(X_train)
    y_test_pred = RFC.predict(X_test)
    
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))
    oob_err.append(1 - RFC.oob_score_)

# %%
plt.plot(tree_arr, train_err, 'b-o', label = 'train')
plt.plot(tree_arr, test_err, 'r-o', label = 'test')
plt.plot(tree_arr, oob_err, 'g-o', label = 'oob')
#plt.xlim([np.max(layer_sizes_arr), np.min(layer_sizes_arr)])
plt.title('Error vs. number of trees')
plt.xlabel('Number of trees')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
min_oob_error = np.min(oob_err)
print(min_train_err, min_test_err, min_oob_error)

# Оптимальное количество деревьев:
tree_opt = tree_arr[test_err == min_test_err]
print("Оптимальное число деревьев:{}".format(tree_opt))

# Минимум oob ошибки достигается при количестве деревьев:
oob_opt = tree_arr[oob_err == min_oob_error]
print("Минимум oob ошибки при числе деревьев:{}".format(oob_opt))
# Out:
# 0.00625 0.65 0.75
# Оптимальное число деревьев:[31]
# Минимум oob ошибки при числе деревьев:[76]

# %%
from sklearn.ensemble import GradientBoostingClassifier
GBC = GradientBoostingClassifier(n_estimators=100, random_state=42)
GBC.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=42, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
y_train_pred = GBC.predict(X_train)
y_test_pred = GBC.predict(X_test)

# %%
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.00625 0.7125

# %%
tree_arr = np.arange(16, 101, 5)
test_err = []
train_err = []
GBC = GradientBoostingClassifier(n_estimators=1, random_state=42)
for tree in tree_arr:
    GBC.set_params(n_estimators=tree)
    GBC.fit(X_train, y_train)

    y_train_pred = GBC.predict(X_train)
    y_test_pred = GBC.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.plot(tree_arr, train_err, 'b-o', label = 'train')
plt.plot(tree_arr, test_err, 'r-o', label = 'test')
#plt.xlim([np.max(layer_sizes_arr), np.min(layer_sizes_arr)])
plt.title('Error vs. number of trees')
plt.xlabel('Number of trees')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)


# Оптимальное количество деревьев:
tree_opt = tree_arr[test_err == min_test_err]
print("Оптимальное число деревьев:{}".format(tree_opt))

# в дальнейшем при усложнении модели (с 45 деревьев) ошибка на тестовой выборке возрастает.
# Out:
# 0.00625 0.675
# Оптимальное число деревьев:[46]

# %%
# Общие выводы:

# В рамках лабораторных работ были опробованы различные функции библиотек numpy, pandas, matplotlib,
# различные алгоритмы обучения (метод K-ближайших соседей, метод главных компонент и другие)
# На выбранном датасете лучше всего себя проявила полносвязная нейронная сеть с оптимальное числом нейронов:[2 3]
# У нее лучшая точность предсказаний по сравнению с другими методами обучения.
# При большем числе нейронов ошибка не увеличивается
